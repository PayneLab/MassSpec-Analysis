# %%
import nbimporter
from readin import *
# %run readin.ipynb

fig = plt.figure()
plt.title("Exaggerated Curve")

plt.axhline(y=0.003, color='r')
plt.axvline(x=.997, color='r')
plt.axvline(x=0.004, color='g')
plt.axhline(y=.994, color='g')
plt.ylim(0, 1) 
plt.xlim(0, 1) 
example_bad = {.999:0,.999:1}
example_nu = {0:0,1:1}
example_good = {0:5,1:5}
plt.plot(example_good.values(), example_good.keys(), label="Very Strong Sample", color="Green")
plt.plot(example_nu.values(), example_nu.keys(), label="Only Noise Detected", color='orange')
plt.plot(example_bad.values(), example_bad.keys(), label="High Negative Control", color='Red')

plt.legend(loc='lower right')
fig.savefig("ex_curve.jpg", dpi=300)
plt.show()
